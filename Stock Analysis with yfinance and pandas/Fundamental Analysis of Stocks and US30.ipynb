# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
yf.Ticker('AAPL').info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 154000,
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. In addition, the company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; AirPods Max, an over-ear wireless headphone; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, and iPod touch. Further, it provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. Additionally, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.',
#  'city': 'Cupertino',
#  'phone': '408 996 1010',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.apple.com',
#  'maxAge': 1,
#  'address1': 'One Apple Park Way',
#  'industry': 'Consumer Electronics',
#  'ebitdaMargins': 0.33842,
#  'profitMargins': 0.26407,
#  'grossMargins': 0.43322,
#  'operatingCashflow': 116425998336,
#  'revenueGrowth': 0.086,
#  'operatingMargins': 0.30926,
#  'ebitda': 130633998336,
#  'targetLowPrice': 157,
#  'recommendationKey': 'buy',
#  'grossProfits': 152836000000,
#  'freeCashflow': 84384628736,
#  'targetMedianPrice': 190,
#  'currentPrice': 143.78,
#  'earningsGrowth': 0.086,
#  'currentRatio': 0.927,
#  'returnOnAssets': 0.21695,
#  'numberOfAnalystOpinions': 43,
#  'targetMeanPrice': 188.92,
#  'debtToEquity': 178.016,
#  'returnOnEquity': 1.49271,
#  'targetHighPrice': 214,
#  'totalCash': 51511001088,
#  'totalDebt': 119980998656,
#  'totalRevenue': 386017001472,
#  'totalCashPerShare': 3.183,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 23.471,
#  'quickRatio': 0.76,
#  'recommendationMean': 1.9,
#  'exchange': 'NMS',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'messageBoardId': 'finmb_24937',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 6.069,
#  'beta3Year': None,
#  'enterpriseToEbitda': 17.934,
#  '52WeekChange': 0.15383995,
#  'morningStarRiskRating': None,
#  'forwardEps': 6.56,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 16185199616,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 4.158,
#  'sharesShort': 108695931,
#  'sharesPercentSharesOut': 0.0067000003,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1632528000,
#  'heldPercentInstitutions': 0.59597,
#  'netIncomeToCommon': 101934997504,
#  'trailingEps': 6.137,
#  'lastDividendValue': 0.23,
#  'SandP52WeekChange': -0.034792125,
#  'priceToBook': 34.579124,
#  'heldPercentInsiders': 0.00072999997,
#  'nextFiscalYearEnd': 1695600000,
#  'yield': None,
#  'mostRecentQuarter': 1648252800,
#  'shortRatio': 1.03,
#  'sharesShortPreviousMonthDate': 1649894400,
#  'floatShares': 16168348412,
#  'beta': 1.194642,
#  'enterpriseValue': 2342811598848,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1598832000,
#  'lastSplitFactor': '4:1',
#  'legalType': None,
#  'lastDividendDate': 1651795200,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.058,
#  'priceToSalesTrailing12Months': 6.0285115,
#  'dateShortInterest': 1652400000,
#  'pegRatio': 2.36,
#  'ytdReturn': None,
#  'forwardPE': 21.917683,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0067000003,
#  'sharesShortPriorMonth': 103292182,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 140.52,
#  'regularMarketOpen': 137.39,
#  'twoHundredDayAverage': 159.49625,
#  'trailingAnnualDividendYield': 0.0062624537,
#  'payoutRatio': 0.14310001,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 144.34,
#  'navPrice': None,
#  'averageDailyVolume10Day': 106664300,
#  'regularMarketPreviousClose': 140.52,
#  'fiftyDayAverage': 160.7944,
#  'trailingAnnualDividendRate': 0.88,
#  'open': 137.39,
#  'toCurrency': None,
#  'averageVolume10days': 106664300,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 0.92,
#  'exDividendDate': 1651795200,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 137.14,
#  'currency': 'USD',
#  'trailingPE': 23.428385,
#  'regularMarketVolume': 90601548,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2327107862528,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 97924293,
#  'dayLow': 137.14,
#  'ask': 0,
#  'askSize': 1000,
#  'volume': 90601548,
#  'fiftyTwoWeekHigh': 182.94,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.1,
#  'fiftyTwoWeekLow': 123.13,
#  'bid': 143.32,
#  'tradeable': False,
#  'dividendYield': 0.0064999997,
#  'bidSize': 2200,
#  'dayHigh': 144.34,
#  'regularMarketPrice': 143.78,
#  'preMarketPrice': 143.83,
#  'logo_url': 'https://logo.clearbit.com/apple.com',
#  'trailingPegRatio': 2.4893}

# %%
tickers = ['AAPL', 'MSFT', 'IBM']

# %%
infos = []

for i in tickers:
    infos.append(yf.Ticker(i).info)

# %%
fundamentals = ['dividendYield','marketCap', 'beta', 'forwardPE'] #fundamentals selected that we want to focus on

# %%
df = pd.DataFrame(infos)

# %%
df = df.set_index('symbol')

# %%
df
# Out:
#                zip      sector  fullTimeEmployees  \
# symbol
# AAPL         95014  Technology             154000
# MSFT    98052-6399  Technology             181000
# IBM          10504  Technology             282100
#
#                                       longBusinessSummary       city  \
# symbol
# AAPL    Apple Inc. designs, manufactures, and markets ...  Cupertino
# MSFT    Microsoft Corporation develops, licenses, and ...    Redmond
# IBM     International Business Machines Corporation pr...     Armonk
#
#                phone state        country companyOfficers  \
# symbol
# AAPL    408 996 1010    CA  United States              []
# MSFT    425 882 8080    WA  United States              []
# IBM     914 499 1900    NY  United States              []
#
#                           website  ...  fiftyTwoWeekLow     bid tradeable  \
# symbol                             ...
# AAPL        https://www.apple.com  ...           123.13  143.32     False
# MSFT    https://www.microsoft.com  ...           243.00    0.00     False
# IBM           https://www.ibm.com  ...           114.56  135.01     False
#
#         dividendYield  bidSize   dayHigh  regularMarketPrice  preMarketPrice  \
# symbol
# AAPL           0.0065     2200  144.3400              143.78          143.94
# MSFT           0.0094      900  267.0000              265.90          267.21
# IBM            0.0491     1000  137.5455              136.89          136.72
#
#                                        logo_url  trailingPegRatio
# symbol
# AAPL        https://logo.clearbit.com/apple.com            2.4893
# MSFT    https://logo.clearbit.com/microsoft.com            1.7027
# IBM           https://logo.clearbit.com/ibm.com            1.4237
#
# [3 rows x 152 columns]

# %%
df[df.columns[df.columns.isin(fundamentals)]]
# Out:
#             beta  forwardPE      marketCap  dividendYield
# symbol
# AAPL    1.194642  21.917683  2327107862528         0.0065
# MSFT    0.936160  24.688950  1988673929216         0.0094
# IBM     1.008928  13.124640   122697244672         0.0491

# %%
plt.bar(df.index, df.forwardPE, color=('k','orange','cyan'))
plt.show()

# %%
df2 = pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')[1] #DJI/US30

# %%
tickers = df2.Symbol.to_list()

# %%
tickers
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'CRM',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT']

# %%
infos = []
for i in tickers:
    infos.append(yf.Ticker(i).info)

# %%
infos
# Out:
# [{'zip': '55144-1000',
#   'sector': 'Industrials',
#   'fullTimeEmployees': 95000,
#   'longBusinessSummary': '3M Company operates as a diversified technology company worldwide. It operates through four segments: Safety and Industrial; Transportation and Electronics; Health Care; and Consumer. The Safety and Industrial segment offers industrial abrasives and finishing for metalworking applications; autobody repair solutions; closure systems for personal hygiene products, masking, and packaging materials; electrical products and materials for construction and maintenance, power distribution, and electrical original equipment manufacturers; structural adhesives and tapes; respiratory, hearing, eye, and fall protection solutions; and natural and color-coated mineral granules for shingles. The Transportation and Electronics segment provides ceramic solutions; attachment tapes, films, sound, and temperature management for transportation vehicles; premium large format graphic films for advertising and fleet signage; light management films and electronics assembly solutions; packaging and interconnection solutions; and reflective signage for highway, and vehicle safety. The Healthcare segment offers food safety indicator solutions; health care procedure coding and reimbursement software; skin, wound care, and infection prevention products and solutions; dentistry and orthodontia solutions; and filtration and purification systems. The Consumer segment provides consumer bandages, braces, supports and consumer respirators; cleaning products for the home; retail abrasives, paint accessories, car care DIY products, picture hanging, and consumer air quality solutions; and stationery products. It offers its products through e-commerce and traditional wholesalers, retailers, jobbers, distributors, and dealers. The company was founded in 1902 and is based in St. Paul, Minnesota.',
#   'city': 'Saint Paul',
#   'phone': '651 733 1110',
#   'state': 'MN',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.3m.com',
#   'maxAge': 1,
#   'address1': '3M Center',
#   'industry': 'Conglomerates',
#   'ebitdaMargins': 0.26768,
#   'profitMargins': 0.15838,
#   'grossMargins': 0.46331,
#   'operatingCashflow': 6776999936,
#   'revenueGrowth': -0.002,
#   'operatingMargins': 0.21350999,
#   'ebitda': 9457999872,
#   'targetLowPrice': 118,
#   'recommendationKey': 'hold',
#   'grossProfits': 16579000000,
#   'freeCashflow': 4292875008,
#   'targetMedianPrice': 157,
#   'currentPrice': 147.04,
#   'earningsGrowth': -0.184,
#   'currentRatio': 1.579,
#   'returnOnAssets': 0.10135999,
#   'numberOfAnalystOpinions': 19,
#   'targetMeanPrice': 155.91,
#   'debtToEquity': 117.329,
#   'returnOnEquity': 0.38880002,
#   'targetHighPrice': 210,
#   'totalCash': 3359000064,
#   'totalDebt': 17603999744,
#   'totalRevenue': 35333001216,
#   'totalCashPerShare': 5.903,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 61.241,
#   'quickRatio': 0.893,
#   'recommendationMean': 3.3,
#   'exchange': 'NYQ',
#   'shortName': '3M Company',
#   'longName': '3M Company',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'MMM',
#   'messageBoardId': 'finmb_289194',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.753,
#   'beta3Year': None,
#   'enterpriseToEbitda': 10.286,
#   '52WeekChange': -0.27580774,
#   'morningStarRiskRating': None,
#   'forwardEps': 11.41,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 569059008,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 26.236,
#   'sharesShort': 9660473,
#   'sharesPercentSharesOut': 0.017,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.67644,
#   'netIncomeToCommon': 5596000256,
#   'trailingEps': 9.612,
#   'lastDividendValue': 1.49,
#   'SandP52WeekChange': -0.034792125,
#   'priceToBook': 5.6045127,
#   'heldPercentInsiders': 0.00082,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': 3.24,
#   'sharesShortPreviousMonthDate': 1649894400,
#   'floatShares': 568552387,
#   'beta': 0.919642,
#   'enterpriseValue': 97282088960,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1064880000,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1652918400,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.2,
#   'priceToSalesTrailing12Months': 2.3681664,
#   'dateShortInterest': 1652400000,
#   'pegRatio': 2.06,
#   'ytdReturn': None,
#   'forwardPE': 12.886941,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.017,
#   'sharesShortPriorMonth': 9223918,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 145.79,
#   'regularMarketOpen': 146.74,
#   'twoHundredDayAverage': 168.3448,
#   'trailingAnnualDividendYield': 0.040674943,
#   'payoutRatio': 0.6171,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 148.81,
#   'navPrice': None,
#   'averageDailyVolume10Day': 2695210,
#   'regularMarketPreviousClose': 145.79,
#   'fiftyDayAverage': 148.6432,
#   'trailingAnnualDividendRate': 5.93,
#   'open': 146.74,
#   'toCurrency': None,
#   'averageVolume10days': 2695210,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 5.96,
#   'exDividendDate': 1652918400,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 146.7,
#   'currency': 'USD',
#   'trailingPE': 15.297544,
#   'regularMarketVolume': 2069539,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 83674431488,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 3122620,
#   'dayLow': 146.7,
#   'ask': 149,
#   'askSize': 800,
#   'volume': 2069539,
#   'fiftyTwoWeekHigh': 206.81,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 3.05,
#   'fiftyTwoWeekLow': 139.74,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.040900003,
#   'bidSize': 800,
#   'dayHigh': 148.81,
#   'regularMarketPrice': 147.04,
#   'preMarketPrice': 147.04,
#   'logo_url': 'https://logo.clearbit.com/3m.com',
#   'trailingPegRatio': 2.0048},
#  {'zip': '10285',
#   'sector': 'Financial Services',
#   'fullTimeEmployees': 64000,
#   'longBusinessSummary': "American Express Company, together with its subsidiaries, provides charge and credit payment card products, and travel-related services worldwide. The company operates through three segments: Global Consumer Services Group, Global Commercial Services, and Global Merchant and Network Services. Its products and services include payment and financing products; network services; accounts payable expense management products and services; and travel and lifestyle services. The company's products and services also comprise merchant acquisition and processing, servicing and settlement, point-of-sale marketing, and information products and services for merchants; and fraud prevention services, as well as the design and operation of customer loyalty programs. It sells its products and services to consumers, small businesses, mid-sized companies, and large corporations through mobile and online applications, third-party vendors and business partners, direct mail, telephone, in-house sales teams, and direct response advertising. American Express Company was founded in 1850 and is headquartered in New York, New York.",
#   'city': 'New York',
#   'phone': '212 640 2000',
#   'state': 'NY',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.americanexpress.com',
#   'maxAge': 1,
#   'address1': '200 Vesey Street',
#   'industry': 'Credit Services',
#   'ebitdaMargins': 0,
#   'profitMargins': 0.17291,
#   'grossMargins': 0.69065005,
#   'operatingCashflow': 16245000192,
#   'revenueGrowth': 0.208,
#   'operatingMargins': 0.22427,
#   'ebitda': None,
#   'targetLowPrice': 146,
#   'recommendationKey': 'buy',
#   'grossProfits': 30799000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 202,
#   'currentPrice': 165.37,
#   'earningsGrowth': -0.004,
#   'currentRatio': 1.63,
#   'returnOnAssets': 0.040749997,
#   'numberOfAnalystOpinions': 25,
#   'targetMeanPrice': 197.64,
#   'debtToEquity': 181.374,
#   'returnOnEquity': 0.3384,
#   'targetHighPrice': 230,
#   'totalCash': 25721999360,
#   'totalDebt': 40597000192,
#   'totalRevenue': 45828001792,
#   'totalCashPerShare': 34.157,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 58.962,
#   'quickRatio': 1.609,
#   'recommendationMean': 2.3,
#   'exchange': 'NYQ',
#   'shortName': 'American Express Company',
#   'longName': 'American Express Company',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'AXP',
#   'messageBoardId': 'finmb_92001',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.962,
#   'beta3Year': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': 0.032723427,
#   'morningStarRiskRating': None,
#   'forwardEps': 11.29,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 753059968,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 29.646,
#   'sharesShort': 8791038,
#   'sharesPercentSharesOut': 0.0117,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.87357,
#   'netIncomeToCommon': 7779999744,
#   'trailingEps': 9.996,
#   'lastDividendValue': 0.52,
#   'SandP52WeekChange': -0.034792125,
#   'priceToBook': 5.5781555,
#   'heldPercentInsiders': 0.00168,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': 2.6,
#   'sharesShortPreviousMonthDate': 1649894400,
#   'floatShares': 600317062,
#   'beta': 1.075892,
#   'enterpriseValue': 135748706304,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1128297600,
#   'lastSplitFactor': '10000:8753',
#   'legalType': None,
#   'lastDividendDate': 1649289600,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.061,
#   'priceToSalesTrailing12Months': 2.717411,
#   'dateShortInterest': 1652400000,
#   'pegRatio': 1.17,
#   'ytdReturn': None,
#   'forwardPE': 14.647475,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0146,
#   'sharesShortPriorMonth': 8940066,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 160.51,
#   'regularMarketOpen': 162.7,
#   'twoHundredDayAverage': 172.96335,
#   'trailingAnnualDividendYield': 0.011276556,
#   'payoutRatio': 0.1808,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 166.77,
#   'navPrice': None,
#   'averageDailyVolume10Day': 3020100,
#   'regularMarketPreviousClose': 160.51,
#   'fiftyDayAverage': 176.0838,
#   'trailingAnnualDividendRate': 1.81,
#   'open': 162.7,
#   'toCurrency': None,
#   'averageVolume10days': 3020100,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 2.08,
#   'exDividendDate': 1656547200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 162.7,
#   'currency': 'USD',
#   'trailingPE': 16.543617,
#   'regularMarketVolume': 2403393,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 124533522432,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 3769153,
#   'dayLow': 162.7,
#   'ask': 169.5,
#   'askSize': 1200,
#   'volume': 2403393,
#   'fiftyTwoWeekHigh': 199.55,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 1.35,
#   'fiftyTwoWeekLow': 149.71,
#   'bid': 166,
#   'tradeable': False,
#   'dividendYield': 0.012999999,
#   'bidSize': 800,
#   'dayHigh': 166.77,
#   'regularMarketPrice': 165.37,
#   'preMarketPrice': 166.5,
#   'logo_url': 'https://logo.clearbit.com/americanexpress.com',
#   'trailingPegRatio': 1.2933},
#  {'zip': '91320-1799',
#   'sector': 'Healthcare',
#   'fullTimeEmployees': 24200,
#   'longBusinessSummary': "Amgen Inc. discovers, develops, manufactures, and delivers human therapeutics worldwide. It focuses on inflammation, oncology/hematology, bone health, cardiovascular disease, nephrology, and neuroscience areas. The company's products include Enbrel to treat plaque psoriasis, rheumatoid arthritis, and psoriatic arthritis; Neulasta that reduces the chance of infection due a low white blood cell count in patients cancer; Prolia to treat postmenopausal women with osteoporosis; Xgeva for skeletal-related events prevention; Otezla for the treatment of adult patients with plaque psoriasis, psoriatic arthritis, and oral ulcers associated with Behçet's disease; Aranesp to treat a lower-than-normal number of red blood cells and anemia; KYPROLIS to treat patients with relapsed or refractory multiple myeloma; and Repatha, which reduces the risks of myocardial infarction, stroke, and coronary revascularization. It also markets Nplate, Vectibix, MVASI, Parsabiv, EPOGEN, KANJINTI, BLINCYTO, Aimovig, EVENITY, AMGEVITATM, Sensipar/Mimpara, NEUPOGEN, IMLYGIC, Corlanor, and AVSOLA. Amgen Inc. serves healthcare providers, including physicians or their clinics, dialysis centers, hospitals, and pharmacies. It distributes its products through pharmaceutical wholesale distributors, as well as direct-to-consumer channels. It has collaboration agreements with Novartis Pharma AG; UCB; Bayer HealthCare LLC; BeiGene, Ltd.; Eli Lilly and Company; Datos Health; and Verastem, Inc. to evaluate VS-6766 in combination with lumakrastm (Sotorasib) in patients with KRAS G12C-mutant non-small cell lung cancer. It has an agreement with Kyowa Kirin Co., Ltd. to jointly develop and commercialize KHK4083, a Phase 3-ready anti-OX40 fully human monoclonal antibody for the treatment of atopic dermatitis and other autoimmune diseases; and research and development collaboration with Neumora Therapeutics, Inc. and Plexium, Inc. Amgen Inc. was incorporated in 1980 and is headquartered in Thousand Oaks, California.",
#   'city': 'Thousand Oaks',
#   'phone': '805 447 1000',
#   'state': 'CA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.amgen.com',
#   'maxAge': 1,
#   'address1': 'One Amgen Center Drive',
#   'fax': '805 447 1010',
#   'industry': 'Drug Manufacturers—General',
#   'ebitdaMargins': 0.48988998,
#   'profitMargins': 0.21746999,
#   'grossMargins': 0.75205004,
#   'operatingCashflow': 9320999936,
#   'revenueGrowth': 0.057,
#   'operatingMargins': 0.36661997,
#   'ebitda': 12892000256,
#   'targetLowPrice': 185,
#   'recommendationKey': 'hold',
#   'grossProfits': 19525000000,
#   'freeCashflow': 7442625024,
#   'targetMedianPrice': 250,
#   'currentPrice': 253.05,
#   'earningsGrowth': -0.053,
#   'currentRatio': 1.437,
#   'returnOnAssets': 0.09907,
#   'numberOfAnalystOpinions': 24,
#   'targetMeanPrice': 249.62,
#   'debtToEquity': 4023.362,
#   'returnOnEquity': 1.11668,
#   'targetHighPrice': 295,
#   'totalCash': 6544000000,
#   'totalDebt': 36854001664,
#   'totalRevenue': 26315999232,
#   'totalCashPerShare': 12.25,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 46.763,
#   'quickRatio': 0.902,
#   'recommendationMean': 2.6,
#   'exchange': 'NMS',
#   'shortName': 'Amgen Inc.',
#   'longName': 'Amgen Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'AMGN',
#   'messageBoardId': 'finmb_24816',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 6.288,
#   'beta3Year': None,
#   'enterpriseToEbitda': 12.835,
#   '52WeekChange': 0.063503385,
#   'morningStarRiskRating': None,
#   'forwardEps': 19.03,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 534200000,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 1.715,
#   'sharesShort': 18854769,
#   'sharesPercentSharesOut': 0.0353,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.81206,
#   'netIncomeToCommon': 5722999808,
#   'trailingEps': 10.12,
#   'lastDividendValue': 1.94,
#   'SandP52WeekChange': -0.034792125,
#   'priceToBook': 147.55103,
#   'heldPercentInsiders': 0.00217,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': 5.72,
#   'sharesShortPreviousMonthDate': 1649894400,
#   'floatShares': 533120849,
#   'beta': 0.57991,
#   'enterpriseValue': 165467930624,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 943228800,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1652659200,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.103,
#   'priceToSalesTrailing12Months': 5.136773,
#   'dateShortInterest': 1652400000,
#   'pegRatio': 2.02,
#   'ytdReturn': None,
#   'forwardPE': 13.297425,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0353,
#   'sharesShortPriorMonth': 20749642,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 253.01,
#   'regularMarketOpen': 253.39,
#   'twoHundredDayAverage': 225.34085,
#   'trailingAnnualDividendYield': 0.028536422,
#   'payoutRatio': 0.71269995,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 255.605,
#   'navPrice': None,
#   'averageDailyVolume10Day': 2774260,
#   'regularMarketPreviousClose': 253.01,
#   'fiftyDayAverage': 244.3114,
#   'trailingAnnualDividendRate': 7.22,
#   'open': 253.39,
#   'toCurrency': None,
#   'averageVolume10days': 2774260,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 7.76,
#   'exDividendDate': 1652659200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 252.08,
#   'currency': 'USD',
#   'trailingPE': 25.004942,
#   'regularMarketVolume': 2175019,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 135179313152,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 3141261,
#   'dayLow': 252.08,
#   'ask': 0,
#   'askSize': 800,
#   'volume': 2175019,
#   'fiftyTwoWeekHigh': 258.45,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 2.77,
#   'fiftyTwoWeekLow': 198.64,
#   'bid': 251.4,
#   'tradeable': False,
#   'dividendYield': 0.0307,
#   'bidSize': 800,
#   'dayHigh': 255.605,
#   'regularMarketPrice': 253.05,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/amgen.com',
#   'trailingPegRatio': 1.4541},
#  {'zip': '95014',
#   'sector': 'Technology',
#   'fullTimeEmployees': 154000,
#   'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. In addition, the company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; AirPods Max, an over-ear wireless headphone; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, and iPod touch. Further, it provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. Additionally, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.',
#   'city': 'Cupertino',
#   'phone': '408 996 1010',
#   'state': 'CA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.apple.com',
#   'maxAge': 1,
#   'address1': 'One Apple Park Way',
#   'industry': 'Consumer Electronics',
#   'ebitdaMargins': 0.33842,
#   'profitMargins': 0.26407,
#   'grossMargins': 0.43322,
#   'operatingCashflow': 116425998336,
#   'revenueGrowth': 0.086,
#   'operatingMargins': 0.30926,
#   'ebitda': 130633998336,
#   'targetLowPrice': 157,
#   'recommendationKey': 'buy',
#   'grossProfits': 152836000000,
#   'freeCashflow': 84384628736,
#   'targetMedianPrice': 190,
#   'currentPrice': 143.78,
#   'earningsGrowth': 0.086,
#   'currentRatio': 0.927,
#   'returnOnAssets': 0.21695,
#   'numberOfAnalystOpinions': 43,
#   'targetMeanPrice': 188.92,
#   'debtToEquity': 178.016,
#   'returnOnEquity': 1.49271,
#   'targetHighPrice': 214,
#   'totalCash': 51511001088,
#   'totalDebt': 119980998656,
#   'totalRevenue': 386017001472,
#   'totalCashPerShare': 3.183,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 23.471,
#   'quickRatio': 0.76,
#   'recommendationMean': 1.9,
#   'exchange': 'NMS',
#   'shortName': 'Apple Inc.',
#   'longName': 'Apple Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'AAPL',
#   'messageBoardId': 'finmb_24937',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 6.069,
#   'beta3Year': None,
#   'enterpriseToEbitda': 17.934,
#   '52WeekChange': 0.15383995,
#   'morningStarRiskRating': None,
#   'forwardEps': 6.56,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 16185199616,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 4.158,
#   'sharesShort': 108695931,
#   'sharesPercentSharesOut': 0.0067000003,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1632528000,
#   'heldPercentInstitutions': 0.59597,
#   'netIncomeToCommon': 101934997504,
#   'trailingEps': 6.137,
#   'lastDividendValue': 0.23,
#   'SandP52WeekChange': -0.034792125,
#   'priceToBook': 34.579124,
#   'heldPercentInsiders': 0.00072999997,
#   'nextFiscalYearEnd': 1695600000,
#   'yield': None,
#   'mostRecentQuarter': 1648252800,
#   'shortRatio': 1.03,
#   'sharesShortPreviousMonthDate': 1649894400,
#   'floatShares': 16168348412,
#   'beta': 1.194642,
#   'enterpriseValue': 2342811598848,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1598832000,
#   'lastSplitFactor': '4:1',
#   'legalType': None,
#   'lastDividendDate': 1651795200,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.058,
#   'priceToSalesTrailing12Months': 6.0285115,
#   'dateShortInterest': 1652400000,
#   'pegRatio': 2.36,
#   'ytdReturn': None,
#   'forwardPE': 21.917683,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0067000003,
#   'sharesShortPriorMonth': 103292182,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 140.52,
#   'regularMarketOpen': 137.39,
#   'twoHundredDayAverage': 159.49625,
#   'trailingAnnualDividendYield': 0.0062624537,
#   'payoutRatio': 0.14310001,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 144.34,
#   'navPrice': None,
#   'averageDailyVolume10Day': 106664300,
#   'regularMarketPreviousClose': 140.52,
#   'fiftyDayAverage': 160.7944,
#   'trailingAnnualDividendRate': 0.88,
#   'open': 137.39,
#   'toCurrency': None,
#   'averageVolume10days': 106664300,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 0.92,
#   'exDividendDate': 1651795200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 137.14,
#   'currency': 'USD',
#   'trailingPE': 23.428385,
#   'regularMarketVolume': 90601548,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 2327107862528,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 97924293,
#   'dayLow': 137.14,
#   'ask': 0,
#   'askSize': 1000,
#   'volume': 90601548,
#   'fiftyTwoWeekHigh': 182.94,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 1.1,
#   'fiftyTwoWeekLow': 123.13,
#   'bid': 143.32,
#   'tradeable': False,
#   'dividendYield': 0.0064999997,
#   'bidSize': 2200,
#   'dayHigh': 144.34,
#   'regularMarketPrice': 143.78,
#   'preMarketPrice': 143.98,
#   'logo_url': 'https://logo.clearbit.com/apple.com',
#   'trailingPegRatio': 2.4893},
#  {'zip': '60606-1596',
#   'sector': 'Industrials',
#   'fullTimeEmployees': 142000,
#   'longBusinessSummary': 'The Boeing Company, together with its subsidiaries, designs, develops, manufactures, sales, services, and supports commercial jetliners, military aircraft, satellites, missile defense, human space flight and launch systems, and services worldwide. The company operates through four segments: Commercial Airplanes; Defense, Space & Security; Global Services; and Boeing Capital. The Commercial Airplanes segment provides commercial jet aircraft for passenger and cargo requirements, as well as fleet support services. The Defense, Space & Security segment engages in the research, development, production, and modification of manned and unmanned military aircraft and weapons systems; strategic defense and intelligence systems, which include strategic missile and defense systems, command, control, communications, computers, intelligence, surveillance and reconnaissance, cyber and information solutions, and intelligence systems; and satellite systems, such as government and commercial satellites, and space exploration. The Global Services segment offers products and services, including supply chain and logistics management, engineering, maintenance and modifications, upgrades and conversions, spare parts, pilot and maintenance training systems and services, technical and maintenance documents, and data analytics and digital services to commercial and defense customers. The Boeing Capital segment offers financing services and manages financing exposure for a portfolio of equipment under operating leases, sales-type/finance leases, notes and other receivables, assets held for sale or re-lease, and investments. The company was incorporated in 1916 and is based in Chicago, Illinois.',
#   'city': 'Chicago',
#   'phone': '312 544 2000',
#   'state': 'IL',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.boeing.com',
#   'maxAge': 1,
#   'address1': '100 North Riverside Plaza',
#   'industry': 'Aerospace & Defense',
#   'ebitdaMargins': 0.00085,
#   'profitMargins': -0.07999,
#   'grossMargins': 0.06136,
#   'operatingCashflow': -3244999936,
#   'revenueGrowth': -0.081,
#   'operatingMargins': -0.03344,
#   'ebitda': 52000000,
#   'targetLowPrice': None,
#   'recommendationKey': 'none',
#   'grossProfits': 5190000000,
#   'freeCashflow': -969875008,
#   'targetMedianPrice': None,
#   'currentPrice': 127.73,
#   'earningsGrowth': None,
#   'currentRatio': 1.298,
#   'returnOnAssets': -0.0089300005,
#   'numberOfAnalystOpinions': None,
#   'targetMeanPrice': None,
#   'debtToEquity': None,
#   'returnOnEquity': None,
#   'targetHighPrice': None,
#   'totalCash': 12282000384,
#   'totalDebt': 57741000704,
#   'totalRevenue': 61060001792,
#   'totalCashPerShare': 20.759,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 103.566,
#   'quickRatio': 0.292,
#   'recommendationMean': None,
#   'exchange': 'NYQ',
#   'shortName': 'Boeing Company (The)',
#   'longName': 'The Boeing Company',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BA',
#   'messageBoardId': 'finmb_370857',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 1.984,
#   'beta3Year': None,
#   'enterpriseToEbitda': 2329.974,
#   '52WeekChange': -0.48291636,
#   'morningStarRiskRating': None,
#   'forwardEps': 5.61,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 591635968,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': -26.038,
#   'sharesShort': 11337694,
#   'sharesPercentSharesOut': 0.019199999,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.55351,
#   'netIncomeToCommon': -4883999744,
#   'trailingEps': -8.285,
#   'lastDividendValue': 2.055,
#   'SandP52WeekChange': -0.034792125,
#   'priceToBook': None,
#   'heldPercentInsiders': 0.00117,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': 1.01,
#   'sharesShortPreviousMonthDate': 1649894400,
#   'floatShares': 546878582,
#   'beta': 1.474553,
#   'enterpriseValue': 121158647808,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 865814400,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1581552000,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': 1.2376297,
#   'dateShortInterest': 1652400000,
#   'pegRatio': -6.87,
#   'ytdReturn': None,
#   'forwardPE': 22.76827,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.019199999,
#   'sharesShortPriorMonth': 6912808,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 122.06,
#   'regularMarketOpen': 123.1,
#   'twoHundredDayAverage': 198.2917,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 128.8416,
#   'navPrice': None,
#   'averageDailyVolume10Day': 11453520,
#   'regularMarketPreviousClose': 122.06,
#   'fiftyDayAverage': 162.8,
#   'trailingAnnualDividendRate': 0,
#   'open': 123.1,
#   'toCurrency': None,
#   'averageVolume10days': 11453520,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': 1581552000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 122.74,
#   'currency': 'USD',
#   'regularMarketVolume': 8316207,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 75569668096,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 10315050,
#   'dayLow': 122.74,
#   'ask': 128.76,
#   'askSize': 1100,
#   'volume': 8316207,
#   'fiftyTwoWeekHigh': 258.4,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 117.08,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 1100,
#   'dayHigh': 128.8416,
#   'regularMarketPrice': 127.73,
#   'preMarketPrice': 128.81,
#   'logo_url': 'https://logo.clearbit.com/boeing.com',
#   'trailingPegRatio': 6.5305},
#  {'zip': '60015',
#   'sector': 'Industrials',
#   'fullTimeEmployees': 107700,
#   'longBusinessSummary': "Caterpillar Inc. manufactures and sells construction and mining equipment, diesel and natural gas engines, and industrial gas turbines worldwide. Its Construction Industries segment offers asphalt pavers, backhoe loaders, compactors, cold planers, compact track and multi-terrain loaders, excavators, motorgraders, pipelayers, road reclaimers, site prep tractors, skid steer loaders, telehandlers, and utility vehicles; mini, small, medium, and large excavators; compact, small, and medium wheel loaders; track-type tractors and loaders; and wheel excavators. The Resource Industries segment provides electric rope shovels, draglines, hydraulic shovels, rotary drills, hard rock vehicles, track-type tractors, mining trucks, longwall miners, wheel loaders, off-highway trucks, articulated trucks, wheel tractor scrapers, wheel dozers, fleet management, landfill compactors, soil compactors, machinery components, autonomous ready vehicles and solutions, select work tools, and safety services and mining performance solutions. The Energy & Transportation segment offers reciprocating engines, generator sets, integrated systems and solutions, turbines and turbine-related services, remanufactured reciprocating engines and components, centrifugal gas compressors, diesel-electric locomotives and components, and other rail-related products and services for marine, oil and gas, industrial, and electric power generation sectors. The company's Financial Products segment provides operating and finance leases, installment sale contracts, working capital loans, and wholesale financing plans; and insurance and risk management products for vehicles, power generation facilities, and marine vessels. The All Other operating segment manufactures filters and fluids, undercarriage, ground engaging tools, etc. The company was formerly known as Caterpillar Tractor Co. and changed its name to Caterpillar Inc. in 1986. The company was founded in 1925 and is headquartered in Deerfield, Illinois.",
#   'city': 'Deerfield',
#   'phone': '224-551-4000',
#   'state': 'IL',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.caterpillar.com',
#   'maxAge': 1,
#   'address1': '510 Lake Cook Road',
#   'industry': 'Farm & Heavy Construction Machinery',
#   'address2': 'Suite 100',
#   'ebitdaMargins': 0.19849001,
#   'profitMargins': 0.123330005,
#   'grossMargins': 0.25270998,
#   'operatingCashflow': 5583000064,
#   'revenueGrowth': 0.143,
#   'operatingMargins': 0.156,
#   'ebitda': 10455000064,
#   'targetLowPrice': 164,
#   'recommendationKey': 'buy',
#   'grossProfits': 13189000000,
#   'freeCashflow': 4762250240,
#   'targetMedianPrice': 240,
#   'currentPrice': 212.99,
#   'earningsGrowth': 0.032,
#   'currentRatio': 1.441,
#   'returnOnAssets': 0.06301,
#   'numberOfAnalystOpinions': 25,
#   'targetMeanPrice': 235.44,
#   'debtToEquity': 219.828,
#   'returnOnEquity': 0.38554,
#   'targetHighPrice': 280,
#   'totalCash': 6474999808,
#   'totalDebt': 37583998976,
#   'totalRevenue': 52672999424,
#   'totalCashPerShare': 12.14,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 97.358,
#   'quickRatio': 0.863,
#   'recommendationMean': 2.4,
#   'exchange': 'NYQ',
#   'shortName': 'Caterpillar, Inc.',
#   'longName': 'Caterpillar Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'CAT',
#   'messageBoardId': 'finmb_259378',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.711,
#   'beta3Year': None,
#   'enterpriseToEbitda': 13.656,
#   '52WeekChange': -0.116517365,
#   'morningStarRiskRating': None,
#   'forwardEps': 13.7,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 533374016,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 31.996,
#   'sharesShort': 4966762,
#   'sharesPercentSharesOut': 0.0093,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.70815,
#   'netIncomeToCommon': 6496000000,
#   'trailingEps': 11.923,
#   'lastDividendValue': 1.11,
#   'SandP52WeekChange': -0.034792125,
#   'priceToBook': 6.6567698,
#   'heldPercentInsiders': 0.00227,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': 1.49,
#   'sharesShortPreviousMonthDate': 1649894400,
#   'floatShares': 532067824,
#   'beta': 0.929017,
#   'enterpriseValue': 142777155584,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1121299200,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1650585600,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.005,
#   'priceToSalesTrailing12Months': 2.1567662,
#   'dateShortInterest': 1652400000,
#   'pegRatio': 0.68,
#   'ytdReturn': None,
#   'forwardPE': 15.546716,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0093,
#   'sharesShortPriorMonth': 5432173,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 209.31,
#   'regularMarketOpen': 211.55,
#   'twoHundredDayAverage': 207.2551,
#   'trailingAnnualDividendYield': 0.021212555,
#   'payoutRatio': 0.36580002,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 213.625,
#   'navPrice': None,
#   'averageDailyVolume10Day': 3096440,
#   'regularMarketPreviousClose': 209.31,
#   'fiftyDayAverage': 216.1142,
#   'trailingAnnualDividendRate': 4.44,
#   'open': 211.55,
#   'toCurrency': None,
#   'averageVolume10days': 3096440,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 4.44,
#   'exDividendDate': 1650585600,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 210.4,
#   'currency': 'USD',
#   'trailingPE': 17.863792,
#   'regularMarketVolume': 2015957,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 113603338240,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 3512193,
#   'dayLow': 210.4,
#   'ask': 215.65,
#   'askSize': 800,
#   'volume': 2015957,
#   'fiftyTwoWeekHigh': 246.69,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 2.45,
#   'fiftyTwoWeekLow': 179.67,
#   'bid': 208.74,
#   'tradeable': False,
#   'dividendYield': 0.0212,
#   'bidSize': 800,
#   'dayHigh': 213.625,
#   'regularMarketPrice': 212.99,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/caterpillar.com'},
#  {'zip': '94583-2324',
#   'sector': 'Energy',
#   'fullTimeEmployees': 42595,
#   'longBusinessSummary': 'Chevron Corporation, through its subsidiaries, engages in integrated energy and chemicals operations worldwide. The company operates in two segments, Upstream and Downstream. The Upstream segment is involved in the exploration, development, production, and transportation of crude oil and natural gas; processing, liquefaction, transportation, and regasification associated with liquefied natural gas; transportation of crude oil through pipelines; and transportation, storage, and marketing of natural gas, as well as operates a gas-to-liquids plant. The Downstream segment engages in refining crude oil into petroleum products; marketing crude oil, refined products, and lubricants; manufacturing and marketing of renewable fuels; transporting crude oil and refined products by pipeline, marine vessel, motor equipment, and rail car; and manufacturing and marketing of commodity petrochemicals, plastics for industrial uses, and fuel and lubricant additives. It is also involved in the cash management and debt financing activities; insurance operations; real estate activities; and technology businesses. The company was formerly known as ChevronTexaco Corporation and changed its name to Chevron Corporation in 2005. Chevron Corporation was founded in 1879 and is based in San Ramon, California.',
#   'city': 'San Ramon',
#   'phone': '925 842 1000',
#   'state': 'CA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.chevron.com',
#   'maxAge': 1,
#   'address1': '6001 Bollinger Canyon Road',
#   'industry': 'Oil & Gas Integrated',
#   'ebitdaMargins': 0.21779,
#   'profitMargins': 0.115959994,
#   'grossMargins': 0.40935,
#   'operatingCashflow': 33087000576,
#   'revenueGrowth': 0.683,
#   'operatingMargins': 0.12197,
#   'ebitda': 38513999872,
#   'targetLowPrice': 130,
#   'recommendationKey': 'buy',
#   'grossProfits': 66234000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 181,
#   'currentPrice': 167.82,
#   'earningsGrowth': 3.473,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': 28,
#   'targetMeanPrice': 175.41,
#   'debtToEquity': 24.919,
#   'returnOnEquity': None,
#   'targetHighPrice': 213,
#   'totalCash': 5674999808,
#   'totalDebt': 34872000512,
#   'totalRevenue': 176843997184,
#   'totalCashPerShare': 2.914,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 92.025,
#   'quickRatio': None,
#   'recommendationMean': 2.3,
#   'exchange': 'NYQ',
#   'shortName': 'Chevron Corporation',
#   'longName': 'Chevron Corporation',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': True,
#   'gmtOffSetMilliseconds': '-14400000',
#   'underlyingSymbol': None,
#   'quoteType': 'EQUITY',
#   'symbol': 'CVX',
#   'underlyingExchangeSymbol': None,
#   'headSymbol': None,
#   'messageBoardId': 'finmb_98506',
#   'uuid': '030410ed-236a-3375-b5de-4212d6028be6',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 1.895,
#   'beta3Year': None,
#   'enterpriseToEbitda': 8.703,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': 9.51,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 1927689984,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 70.479,
#   'sharesShort': 22390061,
#   'sharesPercentSharesOut': 0.0114,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.65876997,
#   'netIncomeToCommon': 20507000832,
#   'trailingEps': 5.173,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': 2.381135,
#   'heldPercentInsiders': 0.00068000006,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': 2.19,
#   'sharesShortPreviousMonthDate': 1648684800,
#   'floatShares': 1907122139,
#   'beta': 1.135294,
#   'enterpriseValue': 335193178112,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1095033600,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 3.545,
#   'priceToSalesTrailing12Months': 1.829324,
#   'dateShortInterest': 1651190400,
#   'pegRatio': 0.6,
#   'ytdReturn': None,
#   'forwardPE': 17.646688,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0114,
#   'sharesShortPriorMonth': 22265855,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 166.86,
#   'regularMarketOpen': 168.88,
#   'twoHundredDayAverage': 130.45856,
#   'trailingAnnualDividendYield': 0.031523433,
#   'payoutRatio': 0.5113,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 171.04,
#   'navPrice': None,
#   'averageDailyVolume10Day': 11040730,
#   'regularMarketPreviousClose': 166.86,
#   'fiftyDayAverage': 166.0832,
#   'trailingAnnualDividendRate': 5.26,
#   'open': 168.88,
#   'averageVolume10days': 11040730,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 5.68,
#   'exDividendDate': 1652832000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 164.09,
#   'currency': 'USD',
#   'trailingPE': 32.441525,
#   'regularMarketVolume': 8964536,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 323504963584,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 15175619,
#   'dayLow': 164.09,
#   'ask': 168.15,
#   'askSize': 800,
#   'volume': 8964536,
#   'fiftyTwoWeekHigh': 177.93,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 4.47,
#   'fiftyTwoWeekLow': 92.86,
#   'bid': 167.88,
#   'tradeable': False,
#   'dividendYield': 0.033800002,
#   'bidSize': 900,
#   'dayHigh': 171.04,
#   'regularMarketPrice': 167.82,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/chevron.com'},
#  {'zip': '95134',
#   'sector': 'Technology',
#   'fullTimeEmployees': 79500,
#   'longBusinessSummary': 'Cisco Systems, Inc. designs, manufactures, and sells Internet Protocol based networking and other products related to the communications and information technology industry in the Americas, Europe, the Middle East, Africa, the Asia Pacific, Japan, and China. It provides infrastructure platforms, including networking technologies of switching, routing, wireless, and data center products that are designed to work together to deliver networking capabilities, and transport and/or store data. The company also offers collaboration products comprising unified communications, Cisco TelePresence, and conferencing, as well as the Internet of Things and analytics software. In addition, it provides security products, such as network security, cloud and email security, identity and access management, advanced threat protection, and unified threat management products. Further, the company offers a range of service and support options for its customers, including technical support and advanced services. It serves businesses of various sizes, public institutions, governments, and service providers. The company sells its products and services directly, as well as through systems integrators, service providers, other resellers, and distributors. Cisco Systems, Inc. has strategic alliances with other companies. Cisco Systems, Inc. was incorporated in 1984 and is headquartered in San Jose, California.',
#   'city': 'San Jose',
#   'phone': '408 526 4000',
#   'state': 'CA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.cisco.com',
#   'maxAge': 1,
#   'address1': '170 West Tasman Drive',
#   'industry': 'Communication Equipment',
#   'ebitdaMargins': 0.31019,
#   'profitMargins': 0.22939,
#   'grossMargins': 0.63300997,
#   'operatingCashflow': 14272000000,
#   'revenueGrowth': 0.064,
#   'operatingMargins': 0.27347,
#   'ebitda': 15989999616,
#   'targetLowPrice': 45,
#   'recommendationKey': 'buy',
#   'grossProfits': 31894000000,
#   'freeCashflow': 10487374848,
#   'targetMedianPrice': 62.5,
#   'currentPrice': 42.94,
#   'earningsGrowth': 0.183,
#   'currentRatio': 1.42,
#   'returnOnAssets': 0.092810005,
#   'numberOfAnalystOpinions': 24,
#   'targetMeanPrice': 62.74,
#   'debtToEquity': 31.927,
#   'returnOnEquity': 0.30082,
#   'targetHighPrice': 73,
#   'totalCash': 21116000256,
#   'totalDebt': 12609999872,
#   'totalRevenue': 51548999680,
#   'totalCashPerShare': 5.083,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 12.247,
#   'quickRatio': 1.201,
#   'recommendationMean': 2.5,
#   'exchange': 'NMS',
#   'shortName': 'Cisco Systems, Inc.',
#   'longName': 'Cisco Systems, Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': True,
#   'gmtOffSetMilliseconds': '-14400000',
#   'underlyingSymbol': None,
#   'quoteType': 'EQUITY',
#   'symbol': 'CSCO',
#   'underlyingExchangeSymbol': None,
#   'headSymbol': None,
#   'messageBoardId': 'finmb_19691',
#   'uuid': '85fd1bb0-e226-3a6a-b3e9-b5dc1a4952f1',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 3.782,
#   'beta3Year': None,
#   'enterpriseToEbitda': 12.193,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': 3.68,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 4217609984,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 10.126,
#   'sharesShort': 36088498,
#   'sharesPercentSharesOut': 0.0087,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1627689600,
#   'heldPercentInstitutions': 0.75448996,
#   'netIncomeToCommon': 11825000448,
#   'trailingEps': 2.69,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': 4.2405686,
#   'heldPercentInsiders': 0.00067000004,
#   'nextFiscalYearEnd': 1690761600,
#   'yield': None,
#   'mostRecentQuarter': 1643414400,
#   'shortRatio': 1.85,
#   'sharesShortPreviousMonthDate': 1648684800,
#   'floatShares': 4150263082,
#   'beta': 0.946568,
#   'enterpriseValue': 194965143552,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 953769600,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.168,
#   'priceToSalesTrailing12Months': 3.513243,
#   'dateShortInterest': 1651190400,
#   'pegRatio': 1.97,
#   'ytdReturn': None,
#   'forwardPE': 11.668478,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0087,
#   'sharesShortPriorMonth': 34439464,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 41.72,
#   'regularMarketOpen': 41.86,
#   'twoHundredDayAverage': 55.6462,
#   'trailingAnnualDividendYield': 0.0352349,
#   'payoutRatio': 0.5305,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 43,
#   'navPrice': None,
#   'averageDailyVolume10Day': 35368260,
#   'regularMarketPreviousClose': 41.72,
#   'fiftyDayAverage': 51.2906,
#   'trailingAnnualDividendRate': 1.47,
#   'open': 41.86,
#   'averageVolume10days': 35368260,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 1.52,
#   'exDividendDate': 1649116800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 41.52,
#   'currency': 'USD',
#   'trailingPE': 15.962825,
#   'regularMarketVolume': 46148684,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 181104164864,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 23242463,
#   'dayLow': 41.52,
#   'ask': 42.89,
#   'askSize': 4000,
#   'volume': 46148684,
#   'fiftyTwoWeekHigh': 64.29,
#   'fromCurrency': None,
# ...
#   'profitMargins': 0.51101,
#   'grossMargins': 0.97186,
#   'operatingCashflow': 16106000384,
#   'revenueGrowth': 0.255,
#   'operatingMargins': 0.67595,
#   'ebitda': 19018999808,
#   'targetLowPrice': 225,
#   'recommendationKey': 'buy',
#   'grossProfits': 23375000000,
#   'freeCashflow': 11844625408,
#   'targetMedianPrice': 270,
#   'currentPrice': 199.03,
#   'earningsGrowth': 0.234,
#   'currentRatio': 1.288,
#   'returnOnAssets': 0.14049,
#   'numberOfAnalystOpinions': 37,
#   'targetMeanPrice': 268.92,
#   'debtToEquity': 58.426,
#   'returnOnEquity': 0.37362,
#   'targetHighPrice': 310,
#   'totalCash': 13528999936,
#   'totalDebt': 21027000320,
#   'totalRevenue': 26936999936,
#   'totalCashPerShare': 6.495,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 12.766,
#   'quickRatio': 0.925,
#   'recommendationMean': 1.8,
#   'exchange': 'NYQ',
#   'shortName': 'Visa Inc.',
#   'longName': 'Visa Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': True,
#   'gmtOffSetMilliseconds': '-14400000',
#   'underlyingSymbol': None,
#   'quoteType': 'EQUITY',
#   'symbol': 'V',
#   'underlyingExchangeSymbol': None,
#   'headSymbol': None,
#   'messageBoardId': 'finmb_38043467',
#   'uuid': '5206560a-306a-3e08-9a43-7fd258eb57ce',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 16.871,
#   'beta3Year': None,
#   'enterpriseToEbitda': 23.895,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': None,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': None,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': None,
#   'sharesShort': 26566643,
#   'sharesPercentSharesOut': 0.0127,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1632960000,
#   'heldPercentInstitutions': 0.96185994,
#   'netIncomeToCommon': 13454999552,
#   'trailingEps': None,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': None,
#   'heldPercentInsiders': 0.00176,
#   'nextFiscalYearEnd': 1696032000,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': 3.44,
#   'sharesShortPreviousMonthDate': 1648684800,
#   'floatShares': 1642740455,
#   'beta': 0.921568,
#   'enterpriseValue': 454458212352,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1426723200,
#   'lastSplitFactor': '4:1',
#   'legalType': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.205,
#   'priceToSalesTrailing12Months': None,
#   'dateShortInterest': 1651190400,
#   'pegRatio': 1.52,
#   'ytdReturn': None,
#   'forwardPE': None,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0162,
#   'sharesShortPriorMonth': 26503385,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 197.37,
#   'regularMarketOpen': 199.67,
#   'twoHundredDayAverage': 216.44345,
#   'trailingAnnualDividendYield': None,
#   'payoutRatio': 0.2182,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 201.66,
#   'navPrice': None,
#   'averageDailyVolume10Day': 7814830,
#   'regularMarketPreviousClose': 197.37,
#   'fiftyDayAverage': 211.3564,
#   'trailingAnnualDividendRate': None,
#   'open': 199.67,
#   'averageVolume10days': 7814830,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 1.5,
#   'exDividendDate': 1652313600,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 194.02,
#   'currency': 'USD',
#   'regularMarketVolume': 6966533,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': None,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 8044357,
#   'dayLow': 194.02,
#   'ask': 200,
#   'askSize': 1100,
#   'volume': 6966533,
#   'fiftyTwoWeekHigh': 252.67,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 0.6,
#   'fiftyTwoWeekLow': 186.67,
#   'bid': 199.03,
#   'tradeable': False,
#   'dividendYield': 0.0075,
#   'bidSize': 1100,
#   'dayHigh': 201.66,
#   'regularMarketPrice': 199.03,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/usa.visa.com'},
#  {'zip': '60015',
#   'sector': 'Healthcare',
#   'fullTimeEmployees': 315000,
#   'longBusinessSummary': 'Walgreens Boots Alliance, Inc. operates as a pharmacy-led health and beauty retail company. It operates through two segments, the United States and International. The United States segment sells prescription drugs and an assortment of retail products, including health, wellness, beauty, personal care, consumable, and general merchandise products through its retail drugstores. It also provides central specialty pharmacy services and mail services. As of August 31, 2021, this segment operated 8,965 retail stores under the Walgreens and Duane Reade brands in the United States; and five specialty pharmacies. The International segment sells prescription drugs; and health and wellness, beauty, personal care, and other consumer products through its pharmacy-led health and beauty retail stores and optical practices, as well as through boots.com and an integrated mobile application. It also engages in pharmaceutical wholesaling and distribution business in Germany. As of August 31, 2021, this segment operated 4,031 retail stores under the Boots, Benavides, and Ahumada in the United Kingdom, Thailand, Norway, the Republic of Ireland, the Netherlands, Mexico, and Chile; and 548 optical practices, including 160 on a franchise basis. Walgreens Boots Alliance, Inc. was founded in 1901 and is based in Deerfield, Illinois.',
#   'city': 'Deerfield',
#   'phone': '847 315 3700',
#   'state': 'IL',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.walgreensbootsalliance.com',
#   'maxAge': 1,
#   'address1': '108 Wilmot Road',
#   'industry': 'Pharmaceutical Retailers',
#   'ebitdaMargins': 0.04433,
#   'profitMargins': 0.04625,
#   'grossMargins': 0.22022,
#   'operatingCashflow': 5183000064,
#   'revenueGrowth': 0.03,
#   'operatingMargins': 0.03135,
#   'ebitda': 6026999808,
#   'targetLowPrice': 40,
#   'recommendationKey': 'hold',
#   'grossProfits': 28067000000,
#   'freeCashflow': 7857249792,
#   'targetMedianPrice': 49.5,
#   'currentPrice': 40.96,
#   'earningsGrowth': -0.136,
#   'currentRatio': 0.741,
#   'returnOnAssets': 0.02902,
#   'numberOfAnalystOpinions': 16,
#   'targetMeanPrice': 48.52,
#   'debtToEquity': 121.734,
#   'returnOnEquity': 0.21486999,
#   'targetHighPrice': 52.3,
#   'totalCash': 1887000064,
#   'totalDebt': 38563999744,
#   'totalRevenue': 135948001280,
#   'totalCashPerShare': 2.185,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 157.211,
#   'quickRatio': 0.322,
#   'recommendationMean': 3.1,
#   'exchange': 'NMS',
#   'shortName': 'Walgreens Boots Alliance, Inc.',
#   'longName': 'Walgreens Boots Alliance, Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': True,
#   'gmtOffSetMilliseconds': '-14400000',
#   'underlyingSymbol': None,
#   'quoteType': 'EQUITY',
#   'symbol': 'WBA',
#   'underlyingExchangeSymbol': None,
#   'headSymbol': None,
#   'messageBoardId': 'finmb_93624',
#   'uuid': '888fa4a2-1f3d-3718-83dd-229207680ca9',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 0.576,
#   'beta3Year': None,
#   'enterpriseToEbitda': 12.988,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': 5.1,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 863945024,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 27.062,
#   'sharesShort': 24527087,
#   'sharesPercentSharesOut': 0.028399998,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1630368000,
#   'heldPercentInstitutions': 0.61285996,
#   'netIncomeToCommon': 5926000128,
#   'trailingEps': 2.933,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': 1.5135614,
#   'heldPercentInsiders': 0.17322999,
#   'nextFiscalYearEnd': 1693440000,
#   'yield': None,
#   'mostRecentQuarter': 1646006400,
#   'shortRatio': 2.96,
#   'sharesShortPreviousMonthDate': 1648684800,
#   'floatShares': 714288828,
#   'beta': 0.548529,
#   'enterpriseValue': 78278991872,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 919123200,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.139,
#   'priceToSalesTrailing12Months': 0.26029944,
#   'dateShortInterest': 1651190400,
#   'pegRatio': 3.49,
#   'ytdReturn': None,
#   'forwardPE': 8.031372,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0342,
#   'sharesShortPriorMonth': 20308428,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 40.61,
#   'regularMarketOpen': 40.85,
#   'twoHundredDayAverage': 47.89115,
#   'trailingAnnualDividendYield': 0.046294015,
#   'payoutRatio': 0.2778,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 41.045,
#   'navPrice': None,
#   'averageDailyVolume10Day': 7363200,
#   'regularMarketPreviousClose': 40.61,
#   'fiftyDayAverage': 44.5662,
#   'trailingAnnualDividendRate': 1.88,
#   'open': 40.85,
#   'averageVolume10days': 7363200,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 1.91,
#   'exDividendDate': 1652918400,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 39.715,
#   'currency': 'USD',
#   'trailingPE': 13.965222,
#   'regularMarketVolume': 7370382,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 35387187200,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 7449328,
#   'dayLow': 39.715,
#   'ask': 40.97,
#   'askSize': 1800,
#   'volume': 7370382,
#   'fiftyTwoWeekHigh': 55.82,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 3.26,
#   'fiftyTwoWeekLow': 39.715,
#   'bid': 40.9,
#   'tradeable': False,
#   'dividendYield': 0.043899998,
#   'bidSize': 1400,
#   'dayHigh': 41.045,
#   'regularMarketPrice': 40.96,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/walgreensbootsalliance.com'},
#  {'zip': '72716',
#   'sector': 'Consumer Defensive',
#   'fullTimeEmployees': 2300000,
#   'longBusinessSummary': "Walmart Inc. engages in the operation of retail, wholesale, and other units worldwide. The company operates through three segments: Walmart U.S., Walmart International, and Sam's Club. It operates supercenters, supermarkets, hypermarkets, warehouse clubs, cash and carry stores, and discount stores; membership-only warehouse clubs; ecommerce websites, such as walmart.com, walmart.com.mx, walmart.ca, flipkart.com, and samsclub.com; and mobile commerce applications. The company offers grocery and consumables, which includes dairy, meat, bakery, deli, produce, dry, chilled or frozen packaged foods, alcoholic and nonalcoholic beverages, floral, snack foods, candy, other grocery items, health and beauty aids, paper goods, laundry and home care, baby care, pet supplies, and other consumable items; and health and wellness products covering pharmacy, over-the-counter drugs and other medical products, and optical and hearing services. It also provides gasoline stations and tobacco; home improvement, outdoor living, gardening, furniture, apparel, jewelry, tools and power equipment, housewares, toys, seasonal items, mattresses, and tire and battery centers; and consumer electronics and accessories, software, video games, office supplies, appliances, and third-party gift cards. In addition, the company offers fuel and financial services and related products, including money orders, prepaid cards, money transfers, and check cashing and bill payment, as well as various types of installment lending. It operates approximately 10,500 stores and various e-commerce websites under 46 banners in 24 countries. The company was formerly known as Wal-Mart Stores, Inc. and changed its name to Walmart Inc. in February 2018. The company was founded in 1945 and is based in Bentonville, Arkansas.",
#   'city': 'Bentonville',
#   'phone': '479 273 4000',
#   'state': 'AR',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.stock.walmart.com',
#   'maxAge': 1,
#   'address1': '702 South West 8th Street',
#   'industry': 'Discount Stores',
#   'ebitdaMargins': 0.0639,
#   'profitMargins': 0.02387,
#   'grossMargins': 0.25099,
#   'operatingCashflow': 24181000192,
#   'revenueGrowth': 0.005,
#   'operatingMargins': 0.045289997,
#   'ebitda': 36600000512,
#   'targetLowPrice': 140,
#   'recommendationKey': 'buy',
#   'grossProfits': 143754000000,
#   'freeCashflow': 14521499648,
#   'targetMedianPrice': 167,
#   'currentPrice': 119.2,
#   'earningsGrowth': None,
#   'currentRatio': 0.928,
#   'returnOnAssets': 0.0652,
#   'numberOfAnalystOpinions': 36,
#   'targetMeanPrice': 166.47,
#   'debtToEquity': 63.573,
#   'returnOnEquity': 0.15539,
#   'targetHighPrice': 190,
#   'totalCash': 14759999488,
#   'totalDebt': 58417999872,
#   'totalRevenue': 572753969152,
#   'totalCashPerShare': 5.364,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 205.141,
#   'quickRatio': 0.264,
#   'recommendationMean': 2,
#   'exchange': 'NYQ',
#   'shortName': 'Walmart Inc.',
#   'longName': 'Walmart Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': True,
#   'gmtOffSetMilliseconds': '-14400000',
#   'underlyingSymbol': None,
#   'quoteType': 'EQUITY',
#   'symbol': 'WMT',
#   'underlyingExchangeSymbol': None,
#   'headSymbol': None,
#   'messageBoardId': 'finmb_313055',
#   'uuid': '902d429a-38af-3903-a1d7-3374c3560928',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 0.826,
#   'beta3Year': None,
#   'enterpriseToEbitda': 12.931,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': 6.72,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 2773880064,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 29.616,
#   'sharesShort': 12361771,
#   'sharesPercentSharesOut': 0.0045,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1643587200,
#   'heldPercentInstitutions': 0.32609,
#   'netIncomeToCommon': 13672999936,
#   'trailingEps': 2.84,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': 4.0248513,
#   'heldPercentInsiders': 0.47702,
#   'nextFiscalYearEnd': 1706659200,
#   'yield': None,
#   'mostRecentQuarter': 1643587200,
#   'shortRatio': 1.71,
#   'sharesShortPreviousMonthDate': 1648684800,
#   'floatShares': 1439290817,
#   'beta': 0.55098,
#   'enterpriseValue': 473290768384,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 924566400,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': 0.5772924,
#   'dateShortInterest': 1651190400,
#   'pegRatio': 2.29,
#   'ytdReturn': None,
#   'forwardPE': 17.738096,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0086,
#   'sharesShortPriorMonth': 10632640,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 119.07,
#   'regularMarketOpen': 119.64,
#   'twoHundredDayAverage': 143.85686,
#   'trailingAnnualDividendYield': 0.018392542,
#   'payoutRatio': 0.45169997,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 120.84,
#   'navPrice': None,
#   'averageDailyVolume10Day': 17749810,
#   'regularMarketPreviousClose': 119.07,
#   'fiftyDayAverage': 146.9998,
#   'trailingAnnualDividendRate': 2.19,
#   'open': 119.64,
#   'averageVolume10days': 17749810,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 2.24,
#   'exDividendDate': 1660176000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 117.28,
#   'currency': 'USD',
#   'trailingPE': 41.971832,
#   'regularMarketVolume': 16451978,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 330646487040,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 9340249,
#   'dayLow': 117.28,
#   'ask': 119.24,
#   'askSize': 900,
#   'volume': 16451978,
#   'fiftyTwoWeekHigh': 160.77,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 1.91,
#   'fiftyTwoWeekLow': 117.27,
#   'bid': 119.08,
#   'tradeable': False,
#   'dividendYield': 0.0150999995,
#   'bidSize': 800,
#   'dayHigh': 120.84,
#   'regularMarketPrice': 119.2,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/stock.walmart.com'}]

# %%
df2 = pd.DataFrame(infos)

# %%
df2 = df2.set_index('symbol')

# %%
df2
# Out:
#                zip                  sector  fullTimeEmployees  \
# symbol
# MMM     55144-1000             Industrials              95000
# AXP          10285      Financial Services              64000
# AMGN    91320-1799              Healthcare              24200
# AAPL         95014              Technology             154000
# BA      60606-1596             Industrials             142000
# CAT          60015             Industrials             107700
# CVX     94583-2324                  Energy              42595
# CSCO         95134              Technology              79500
# KO           30313      Consumer Defensive              79000
# DIS          91521  Communication Services             152000
# DOW          48674         Basic Materials              35700
# GS           10282      Financial Services              45100
# HD           30339       Consumer Cyclical             490600
# HON          28202             Industrials              99000
# IBM          10504              Technology             282100
# INTC    95054-1549              Technology             122900
# JNJ          08933              Healthcare             144000
# JPM          10179      Financial Services             273948
# MCD          60607       Consumer Cyclical             100000
# MRK          07033              Healthcare              67000
# MSFT    98052-6399              Technology             181000
# NKE     97005-6453       Consumer Cyclical              73300
# PG           45202      Consumer Defensive             101000
# CRM          94105              Technology              73541
# TRV          10017      Financial Services              30184
# UNH          55343              Healthcare             350000
# VZ           10036  Communication Services             118500
# V       94128-8999      Financial Services              21500
# WBA          60015              Healthcare             315000
# WMT          72716      Consumer Defensive            2300000
#
#                                       longBusinessSummary           city  \
# symbol
# MMM     3M Company operates as a diversified technolog...     Saint Paul
# AXP     American Express Company, together with its su...       New York
# AMGN    Amgen Inc. discovers, develops, manufactures, ...  Thousand Oaks
# AAPL    Apple Inc. designs, manufactures, and markets ...      Cupertino
# BA      The Boeing Company, together with its subsidia...        Chicago
# CAT     Caterpillar Inc. manufactures and sells constr...      Deerfield
# CVX     Chevron Corporation, through its subsidiaries,...      San Ramon
# CSCO    Cisco Systems, Inc. designs, manufactures, and...       San Jose
# KO      The Coca-Cola Company, a beverage company, man...        Atlanta
# DIS     The Walt Disney Company, together with its sub...        Burbank
# DOW     Dow Inc. provides various materials science so...        Midland
# GS      The Goldman Sachs Group, Inc., a financial ins...       New York
# HD      The Home Depot, Inc. operates as a home improv...        Atlanta
# HON     Honeywell International Inc. operates as a div...      Charlotte
# IBM     International Business Machines Corporation pr...         Armonk
# INTC    Intel Corporation engages in the design, manuf...    Santa Clara
# JNJ     Johnson & Johnson researches and develops, man...  New Brunswick
# JPM     JPMorgan Chase & Co. operates as a financial s...       New York
# MCD     McDonald's Corporation operates and franchises...        Chicago
# MRK     Merck & Co., Inc. operates as a healthcare com...     Kenilworth
# MSFT    Microsoft Corporation develops, licenses, and ...        Redmond
# NKE     NIKE, Inc., together with its subsidiaries, de...      Beaverton
# PG      The Procter & Gamble Company provides branded ...     Cincinnati
# CRM     Salesforce, Inc. provides customer relationshi...  San Francisco
# TRV     The Travelers Companies, Inc., through its sub...       New York
# UNH     UnitedHealth Group Incorporated operates as a ...     Minnetonka
# VZ      Verizon Communications Inc., through its subsi...       New York
# V       Visa Inc. operates as a payments technology co...  San Francisco
# WBA     Walgreens Boots Alliance, Inc. operates as a p...      Deerfield
# WMT     Walmart Inc. engages in the operation of retai...    Bentonville
#
#                phone state        country companyOfficers  \
# symbol
# MMM     651 733 1110    MN  United States              []
# AXP     212 640 2000    NY  United States              []
# AMGN    805 447 1000    CA  United States              []
# AAPL    408 996 1010    CA  United States              []
# BA      312 544 2000    IL  United States              []
# CAT     224-551-4000    IL  United States              []
# CVX     925 842 1000    CA  United States              []
# CSCO    408 526 4000    CA  United States              []
# KO      404 676 2121    GA  United States              []
# DIS     818 560 1000    CA  United States              []
# DOW     989 636 1000    MI  United States              []
# GS      212-902-1000    NY  United States              []
# HD      770 433 8211    GA  United States              []
# HON     704 627 6200    NC  United States              []
# IBM     914 499 1900    NY  United States              []
# INTC    408 765 8080    CA  United States              []
# JNJ     732 524 0400    NJ  United States              []
# JPM     212 270 6000    NY  United States              []
# MCD     630 623 3000    IL  United States              []
# MRK     908 740 4000    NJ  United States              []
# MSFT    425 882 8080    WA  United States              []
# NKE     503 671 6453    OR  United States              []
# PG      513 983 1100    OH  United States              []
# CRM     415 901 7000    CA  United States              []
# TRV     917 778 6000    NY  United States              []
# UNH     952 936 1300    MN  United States              []
# VZ      212 395 1000    NY  United States              []
# V       650 432 3200    CA  United States              []
# WBA     847 315 3700    IL  United States              []
# WMT     479 273 4000    AR  United States              []
#
#                                        website  ...  regularMarketPrice  \
# symbol                                          ...
# MMM                         https://www.3m.com  ...              147.04
# AXP            https://www.americanexpress.com  ...              165.37
# AMGN                     https://www.amgen.com  ...              253.05
# AAPL                     https://www.apple.com  ...              143.78
# BA                      https://www.boeing.com  ...              127.73
# CAT                https://www.caterpillar.com  ...              212.99
# CVX                    https://www.chevron.com  ...              167.82
# CSCO                     https://www.cisco.com  ...               42.94
# KO            https://www.coca-colacompany.com  ...               60.98
# DIS       https://www.thewaltdisneycompany.com  ...              102.42
# DOW                        https://www.dow.com  ...               68.11
# GS                https://www.goldmansachs.com  ...              306.80
# HD                   https://www.homedepot.com  ...              287.19
# HON                  https://www.honeywell.com  ...              189.75
# IBM                        https://www.ibm.com  ...              128.48
# INTC                     https://www.intel.com  ...               41.65
# JNJ                        https://www.jnj.com  ...              176.98
# JPM              https://www.jpmorganchase.com  ...              117.34
# MCD            https://corporate.mcdonalds.com  ...              233.91
# MRK                      https://www.merck.com  ...               93.55
# MSFT                 https://www.microsoft.com  ...              252.56
# NKE                       https://www.nike.com  ...              108.00
# PG                  https://www.pginvestor.com  ...              141.79
# CRM                 https://www.salesforce.com  ...              159.65
# TRV                  https://www.travelers.com  ...              168.24
# UNH          https://www.unitedhealthgroup.com  ...              485.73
# VZ                     https://www.verizon.com  ...               49.53
# V                         https://usa.visa.com  ...              199.03
# WBA     https://www.walgreensbootsalliance.com  ...               40.96
# WMT              https://www.stock.walmart.com  ...              119.20
#
#        preMarketPrice                                           logo_url  \
# symbol
# MMM            147.04                   https://logo.clearbit.com/3m.com
# AXP            166.50      https://logo.clearbit.com/americanexpress.com
# AMGN              NaN                https://logo.clearbit.com/amgen.com
# AAPL           143.98                https://logo.clearbit.com/apple.com
# BA             128.81               https://logo.clearbit.com/boeing.com
# CAT               NaN          https://logo.clearbit.com/caterpillar.com
# CVX               NaN              https://logo.clearbit.com/chevron.com
# CSCO              NaN                https://logo.clearbit.com/cisco.com
# KO                NaN     https://logo.clearbit.com/coca-colacompany.com
# DIS               NaN  https://logo.clearbit.com/thewaltdisneycompany...
# DOW               NaN                  https://logo.clearbit.com/dow.com
# GS                NaN         https://logo.clearbit.com/goldmansachs.com
# HD                NaN            https://logo.clearbit.com/homedepot.com
# HON               NaN            https://logo.clearbit.com/honeywell.com
# IBM               NaN                  https://logo.clearbit.com/ibm.com
# INTC              NaN                https://logo.clearbit.com/intel.com
# JNJ               NaN                  https://logo.clearbit.com/jnj.com
# JPM               NaN        https://logo.clearbit.com/jpmorganchase.com
# MCD               NaN  https://logo.clearbit.com/corporate.mcdonalds.com
# MRK               NaN                https://logo.clearbit.com/merck.com
# MSFT              NaN            https://logo.clearbit.com/microsoft.com
# NKE               NaN                 https://logo.clearbit.com/nike.com
# PG                NaN           https://logo.clearbit.com/pginvestor.com
# CRM               NaN           https://logo.clearbit.com/salesforce.com
# TRV               NaN            https://logo.clearbit.com/travelers.com
# UNH               NaN    https://logo.clearbit.com/unitedhealthgroup.com
# VZ                NaN              https://logo.clearbit.com/verizon.com
# V                 NaN             https://logo.clearbit.com/usa.visa.com
# WBA               NaN  https://logo.clearbit.com/walgreensbootsallian...
# WMT               NaN        https://logo.clearbit.com/stock.walmart.com
#
#         trailingPegRatio           fax                      address2  \
# symbol
# MMM               2.0048           NaN                           NaN
# AXP               1.2933           NaN                           NaN
# AMGN              1.4541  805 447 1010                           NaN
# AAPL              2.4893           NaN                           NaN
# BA                6.5305           NaN                           NaN
# CAT                  NaN           NaN                     Suite 100
# CVX                  NaN           NaN                           NaN
# CSCO                 NaN           NaN                           NaN
# KO                   NaN           NaN                           NaN
# DIS                  NaN           NaN                           NaN
# DOW                  NaN  989 832 1456                           NaN
# GS                   NaN           NaN                           NaN
# HD                   NaN           NaN                           NaN
# HON                  NaN           NaN                           NaN
# IBM                  NaN           NaN                           NaN
# INTC                 NaN           NaN                           NaN
# JNJ                  NaN           NaN                           NaN
# JPM                  NaN           NaN                           NaN
# MCD                  NaN           NaN                           NaN
# MRK                  NaN           NaN                           NaN
# MSFT                 NaN           NaN                           NaN
# NKE                  NaN           NaN                           NaN
# PG                   NaN           NaN                           NaN
# CRM                  NaN  415 901 7040  3rd Floor 415 Mission Street
# TRV                  NaN           NaN                           NaN
# UNH                  NaN           NaN           9900 Bren Road East
# VZ                   NaN           NaN                           NaN
# V                    NaN           NaN                           NaN
# WBA                  NaN           NaN                           NaN
# WMT                  NaN           NaN                           NaN
#
#         underlyingSymbol  underlyingExchangeSymbol  headSymbol  \
# symbol
# MMM                  NaN                       NaN         NaN
# AXP                  NaN                       NaN         NaN
# AMGN                 NaN                       NaN         NaN
# AAPL                 NaN                       NaN         NaN
# BA                   NaN                       NaN         NaN
# CAT                  NaN                       NaN         NaN
# CVX                  NaN                       NaN         NaN
# CSCO                 NaN                       NaN         NaN
# KO                   NaN                       NaN         NaN
# DIS                  NaN                       NaN         NaN
# DOW                  NaN                       NaN         NaN
# GS                   NaN                       NaN         NaN
# HD                   NaN                       NaN         NaN
# HON                  NaN                       NaN         NaN
# IBM                  NaN                       NaN         NaN
# INTC                 NaN                       NaN         NaN
# JNJ                  NaN                       NaN         NaN
# JPM                  NaN                       NaN         NaN
# MCD                  NaN                       NaN         NaN
# MRK                  NaN                       NaN         NaN
# MSFT                 NaN                       NaN         NaN
# NKE                  NaN                       NaN         NaN
# PG                   NaN                       NaN         NaN
# CRM                  NaN                       NaN         NaN
# TRV                  NaN                       NaN         NaN
# UNH                  NaN                       NaN         NaN
# VZ                   NaN                       NaN         NaN
# V                    NaN                       NaN         NaN
# WBA                  NaN                       NaN         NaN
# WMT                  NaN                       NaN         NaN
#
#                                         uuid
# symbol
# MMM                                      NaN
# AXP                                      NaN
# AMGN                                     NaN
# AAPL                                     NaN
# BA                                       NaN
# CAT                                      NaN
# CVX     030410ed-236a-3375-b5de-4212d6028be6
# CSCO    85fd1bb0-e226-3a6a-b3e9-b5dc1a4952f1
# KO      5fed318f-9c85-3ad1-b311-20392472c25a
# DIS     aef70f8f-79be-3478-9d04-39acf5bad0ef
# DOW     9510e206-86db-3ea5-bd8f-fbd901232728
# GS      71a75a16-7c33-358b-bb56-1764255c880a
# HD      27178471-f2c4-319c-872d-1545a0f154c7
# HON     b586a6a4-876a-334e-8a5d-322e18a9cb87
# IBM     cbf44511-d041-3c6d-9dd7-3cc0c033122c
# INTC    fc39dab3-4bbe-3356-80d3-0933db783ba0
# JNJ     73aa25b0-87c8-3616-a460-03cbef1b4753
# JPM     bc753df4-b894-3e19-9c58-995ef66d8e67
# MCD     23d8bc2b-33aa-36cd-80f6-61c9e181ef67
# MRK     3fd0c404-d9b9-32ea-a95e-f2db63766fb3
# MSFT    b004b3ec-de24-385e-b2c1-923f10d3fb62
# NKE     31395cb8-4595-3f3c-a5ad-b37464c2ce43
# PG      49f38fe0-3598-34d6-bf4a-0a8791c9c8b9
# CRM     01d3fcca-fdd3-37b7-b601-1bfd3a695ce7
# TRV     f9648b70-41f5-3bd8-a005-3a20a688b790
# UNH     33ae4437-560d-3a42-9aa4-234d48c993c5
# VZ      a708480c-0400-3ea0-b2d3-ca752db5c3b1
# V       5206560a-306a-3e08-9a43-7fd258eb57ce
# WBA     888fa4a2-1f3d-3718-83dd-229207680ca9
# WMT     902d429a-38af-3903-a1d7-3374c3560928
#
# [30 rows x 158 columns]

# %%
df2['dividendYield'].nlargest(5)
# Out:
# symbol
# VZ     0.0531
# IBM    0.0494
# WBA    0.0439
# DOW    0.0418
# MMM    0.0409
# Name: dividendYield, dtype: float64

# %%
plt.figure(figsize=(14,5))
plt.bar(df2['shortName'], df2['dividendYield'])
plt.xticks(rotation=90)
plt.show()
